# %%
import pandas as pd
import json

orders_columns = ['order_id', 'order_date', 'customer_id', 'order_status']

orders = pd.read_csv('C:/Users/Shalini/data_eng/data/retail_db/orders/part-00000', 
    names=orders_columns)

# %%
orders
# Out:
#        order_id             order_date  customer_id     order_status
# 0             1  2013-07-25 00:00:00.0        11599           CLOSED
# 1             2  2013-07-25 00:00:00.0          256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0        12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0         8827           CLOSED
# 4             5  2013-07-25 00:00:00.0        11318         COMPLETE
# ...         ...                    ...          ...              ...
# 68878     68879  2014-07-09 00:00:00.0          778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0         1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0         2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0        10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0         5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
def get_column_names(schemas,ds_name,sorting_key = "column_position"):
    column_details = schemas[ds_name]
    columns = sorted(column_details, key=lambda x: x[sorting_key])
    return [col['column_name'] for col in columns]

# %%
schemas = json.load(open('C:/Users/Shalini/data_eng/data/retail_db/schemas.json'))
schemas
# Out:
# {'departments': [{'column_name': 'department_id',
#    'data_type': 'integer',
#    'column_position': 1},
#   {'column_name': 'department_name',
#    'data_type': 'string',
#    'column_position': 2}],
#  'categories': [{'column_name': 'category_id',
#    'data_type': 'integer',
#    'column_position': 1},
#   {'column_name': 'category_department_id',
#    'data_type': 'integer',
#    'column_position': 2},
#   {'column_name': 'category_name',
#    'data_type': 'string',
#    'column_position': 3}],
#  'orders': [{'column_name': 'order_id',
#    'data_type': 'integer',
#    'column_position': 1},
#   {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2},
#   {'column_name': 'order_customer_id',
#    'data_type': 'timestamp',
#    'column_position': 3},
#   {'column_name': 'order_status',
#    'data_type': 'string',
#    'column_position': 4}],
#  'products': [{'column_name': 'product_id',
#    'data_type': 'integer',
#    'column_position': 1},
#   {'column_name': 'product_cateogry_id',
#    'data_type': 'integer',
#    'column_position': 2},
#   {'column_name': 'product_name', 'data_type': '', 'column_position': 3},
#   {'column_name': 'product_description',
#    'data_type': 'string',
#    'column_position': 4},
#   {'column_name': 'product_price', 'data_type': 'float', 'column_position': 5},
#   {'column_name': 'product_image',
#    'data_type': 'string',
#    'column_position': 6}],
#  'customers': [{'column_name': 'customer_id',
#    'data_type': 'integer',
#    'column_position': 1},
#   {'column_name': 'customer_fname',
#    'data_type': 'string',
#    'column_position': 2},
#   {'column_name': 'customer_lname',
#    'data_type': 'string',
#    'column_position': 3},
#   {'column_name': 'customer_email',
#    'data_type': 'string',
#    'column_position': 4},
#   {'column_name': 'customer_password',
#    'data_type': 'string',
#    'column_position': 5},
#   {'column_name': 'customer_street',
#    'data_type': 'string',
#    'column_position': 6},
#   {'column_name': 'customer_city',
#    'data_type': 'string',
#    'column_position': 7},
#   {'column_name': 'customer_state',
#    'data_type': 'string',
#    'column_position': 8},
#   {'column_name': 'customer_zipcode',
#    'data_type': 'integer',
#    'column_position': 9}],
#  'order_items': [{'column_name': 'order_item_id',
#    'data_type': 'integer',
#    'column_position': 1},
#   {'column_name': 'order_item_order_id',
#    'data_type': 'integer',
#    'column_position': 2},
#   {'column_name': 'order_item_product_id',
#    'data_type': 'integer',
#    'column_position': 3},
#   {'column_name': 'order_item_quantity',
#    'data_type': 'integer',
#    'column_position': 4},
#   {'column_name': 'order_item_subtotal',
#    'data_type': 'float',
#    'column_position': 5},
#   {'column_name': 'order_item_product_price',
#    'data_type': 'float',
#    'column_position': 6}]}

# %%
orders_columns = get_column_names(schemas, 'orders')
orders_columns
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
orders = pd.read_csv('C:/Users/Shalini/data_eng/data/retail_db/orders/part-00000',
                     names=orders_columns)
orders
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
customers_columns = get_column_names(schemas, 'customers')
customers_columns
# Out:
# ['customer_id',
#  'customer_fname',
#  'customer_lname',
#  'customer_email',
#  'customer_password',
#  'customer_street',
#  'customer_city',
#  'customer_state',
#  'customer_zipcode']

# %%
customers = pd.read_csv('C:/Users/Shalini/data_eng/data/retail_db/customers/part-00000',
                        names=customers_columns)

# %%
customers
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 0             XXXXXXXXX          6303 Heather Plaza   Brownsville
# 1             XXXXXXXXX     9526 Noble Embers Ridge     Littleton
# 2             XXXXXXXXX      3422 Blue Pioneer Bend        Caguas
# 3             XXXXXXXXX          8324 Little Common    San Marcos
# 4             XXXXXXXXX      10 Crystal River Mall         Caguas
# ...                 ...                         ...           ...
# 12430         XXXXXXXXX           1221 Cinder Pines       Kaneohe
# 12431         XXXXXXXXX  1525 Jagged Barn Highlands        Caguas
# 12432         XXXXXXXXX    5459 Noble Brook Landing     Levittown
# 12433         XXXXXXXXX        9720 Colonial Parade        Caguas
# 12434         XXXXXXXXX            5736 Honey Downs   Summerville
#
#       customer_state  customer_zipcode
# 0                 TX             78521
# 1                 CO             80126
# 2                 PR               725
# 3                 CA             92069
# 4                 PR               725
# ...              ...               ...
# 12430             HI             96744
# 12431             PR               725
# 12432             NY             11756
# 12433             PR               725
# 12434             SC             29483
#
# [12435 rows x 9 columns]

# %%
# To perform joins in dataframes, we have to first set index on the columns that we want to join on
customers.set_index('customer_id')
# Out:
#             customer_fname customer_lname customer_email customer_password  \
# customer_id
# 1                  Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 3                      Ann          Smith      XXXXXXXXX         XXXXXXXXX
# 4                     Mary          Jones      XXXXXXXXX         XXXXXXXXX
# 5                   Robert         Hudson      XXXXXXXXX         XXXXXXXXX
# ...                    ...            ...            ...               ...
# 12431                 Mary           Rios      XXXXXXXXX         XXXXXXXXX
# 12432               Angela          Smith      XXXXXXXXX         XXXXXXXXX
# 12433             Benjamin         Garcia      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
#
#                         customer_street customer_city customer_state  \
# customer_id
# 1                    6303 Heather Plaza   Brownsville             TX
# 2               9526 Noble Embers Ridge     Littleton             CO
# 3                3422 Blue Pioneer Bend        Caguas             PR
# 4                    8324 Little Common    San Marcos             CA
# 5                10 Crystal River Mall         Caguas             PR
# ...                                 ...           ...            ...
# 12431                 1221 Cinder Pines       Kaneohe             HI
# 12432        1525 Jagged Barn Highlands        Caguas             PR
# 12433          5459 Noble Brook Landing     Levittown             NY
# 12434              9720 Colonial Parade        Caguas             PR
# 12435                  5736 Honey Downs   Summerville             SC
#
#              customer_zipcode
# customer_id
# 1                       78521
# 2                       80126
# 3                         725
# 4                       92069
# 5                         725
# ...                       ...
# 12431                   96744
# 12432                     725
# 12433                   11756
# 12434                     725
# 12435                   29483
#
# [12435 rows x 8 columns]

# %%
orders = orders.set_index('order_customer_id')
orders
# Out:
#                    order_id             order_date     order_status
# order_customer_id
# 11599                     1  2013-07-25 00:00:00.0           CLOSED
# 256                       2  2013-07-25 00:00:00.0  PENDING_PAYMENT
# 12111                     3  2013-07-25 00:00:00.0         COMPLETE
# 8827                      4  2013-07-25 00:00:00.0           CLOSED
# 11318                     5  2013-07-25 00:00:00.0         COMPLETE
# ...                     ...                    ...              ...
# 778                   68879  2014-07-09 00:00:00.0         COMPLETE
# 1117                  68880  2014-07-13 00:00:00.0         COMPLETE
# 2518                  68881  2014-07-19 00:00:00.0  PENDING_PAYMENT
# 10000                 68882  2014-07-22 00:00:00.0          ON_HOLD
# 5533                  68883  2014-07-23 00:00:00.0         COMPLETE
#
# [68883 rows x 3 columns]

# %%
customer_orders = customers.join(orders, how='inner')
customer_orders
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12434        12435          Laura         Horton      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password          customer_street customer_city customer_state  \
# 1             XXXXXXXXX  9526 Noble Embers Ridge     Littleton             CO
# 2             XXXXXXXXX   3422 Blue Pioneer Bend        Caguas             PR
# 2             XXXXXXXXX   3422 Blue Pioneer Bend        Caguas             PR
# 2             XXXXXXXXX   3422 Blue Pioneer Bend        Caguas             PR
# 2             XXXXXXXXX   3422 Blue Pioneer Bend        Caguas             PR
# ...                 ...                      ...           ...            ...
# 12434         XXXXXXXXX         5736 Honey Downs   Summerville             SC
# 12434         XXXXXXXXX         5736 Honey Downs   Summerville             SC
# 12434         XXXXXXXXX         5736 Honey Downs   Summerville             SC
# 12434         XXXXXXXXX         5736 Honey Downs   Summerville             SC
# 12434         XXXXXXXXX         5736 Honey Downs   Summerville             SC
#
#        customer_zipcode  order_id             order_date     order_status
# 1                 80126     22945  2013-12-13 00:00:00.0         COMPLETE
# 2                   725     15192  2013-10-29 00:00:00.0  PENDING_PAYMENT
# 2                   725     33865  2014-02-18 00:00:00.0         COMPLETE
# 2                   725     57963  2013-08-02 00:00:00.0          ON_HOLD
# 2                   725     67863  2013-11-30 00:00:00.0         COMPLETE
# ...                 ...       ...                    ...              ...
# 12434             29483      6160  2013-09-02 00:00:00.0         COMPLETE
# 12434             29483     13544  2013-10-16 00:00:00.0          PENDING
# 12434             29483     42915  2014-04-16 00:00:00.0         COMPLETE
# 12434             29483     51800  2014-06-14 00:00:00.0          ON_HOLD
# 12434             29483     61777  2013-12-26 00:00:00.0         COMPLETE
#
# [68881 rows x 12 columns]

# %%
customer_orders.shape
# Out:
# (68881, 12)

# %%
customer_orders.reset_index()
# Out:
#        index  customer_id customer_fname customer_lname customer_email  \
# 0          1            2           Mary        Barrett      XXXXXXXXX
# 1          2            3            Ann          Smith      XXXXXXXXX
# 2          2            3            Ann          Smith      XXXXXXXXX
# 3          2            3            Ann          Smith      XXXXXXXXX
# 4          2            3            Ann          Smith      XXXXXXXXX
# ...      ...          ...            ...            ...            ...
# 68876  12434        12435          Laura         Horton      XXXXXXXXX
# 68877  12434        12435          Laura         Horton      XXXXXXXXX
# 68878  12434        12435          Laura         Horton      XXXXXXXXX
# 68879  12434        12435          Laura         Horton      XXXXXXXXX
# 68880  12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password          customer_street customer_city customer_state  \
# 0             XXXXXXXXX  9526 Noble Embers Ridge     Littleton             CO
# 1             XXXXXXXXX   3422 Blue Pioneer Bend        Caguas             PR
# 2             XXXXXXXXX   3422 Blue Pioneer Bend        Caguas             PR
# 3             XXXXXXXXX   3422 Blue Pioneer Bend        Caguas             PR
# 4             XXXXXXXXX   3422 Blue Pioneer Bend        Caguas             PR
# ...                 ...                      ...           ...            ...
# 68876         XXXXXXXXX         5736 Honey Downs   Summerville             SC
# 68877         XXXXXXXXX         5736 Honey Downs   Summerville             SC
# 68878         XXXXXXXXX         5736 Honey Downs   Summerville             SC
# 68879         XXXXXXXXX         5736 Honey Downs   Summerville             SC
# 68880         XXXXXXXXX         5736 Honey Downs   Summerville             SC
#
#        customer_zipcode  order_id             order_date     order_status
# 0                 80126     22945  2013-12-13 00:00:00.0         COMPLETE
# 1                   725     15192  2013-10-29 00:00:00.0  PENDING_PAYMENT
# 2                   725     33865  2014-02-18 00:00:00.0         COMPLETE
# 3                   725     57963  2013-08-02 00:00:00.0          ON_HOLD
# 4                   725     67863  2013-11-30 00:00:00.0         COMPLETE
# ...                 ...       ...                    ...              ...
# 68876             29483      6160  2013-09-02 00:00:00.0         COMPLETE
# 68877             29483     13544  2013-10-16 00:00:00.0          PENDING
# 68878             29483     42915  2014-04-16 00:00:00.0         COMPLETE
# 68879             29483     51800  2014-06-14 00:00:00.0          ON_HOLD
# 68880             29483     61777  2013-12-26 00:00:00.0         COMPLETE
#
# [68881 rows x 13 columns]

# %%
customer_orders. \
    reset_index(names= 'customer_id'). \
    groupby('customer_id')['customer_id']. \
    agg(order_count='count'). \
    reset_index(). \
    query('order_count > 10')

# %%
sorted_by_fname = customer_orders.groupby('customer_fname')['customer_fname']. \
    agg(order_count='count'). \
    reset_index(). \
    sort_values('order_count', ascending=True)
sorted_by_fname
# Out:
#     customer_fname  order_count
# 22           Billy           65
# 129          Louis           76
# 193        Vincent           77
# 75           Harry           85
# 116          Keith           88
# ..             ...          ...
# 162         Robert          618
# 97            John          660
# 141        Michael          670
# 83           James          733
# 137           Mary        26166
#
# [200 rows x 2 columns]
